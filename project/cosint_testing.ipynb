# %% [markdown]
# ### 1. Imports

# %%
import numpy as np
import pandas as pd

import astropy.constants as c
import astropy.units as u
import matplotlib.pyplot as plt

import sys
sys.path.append('/home/dasein/repositories/stellar-convolution/packages')

# "Fun for making plots!"
from common.PostProcessingScripts import *

# %% [markdown]
# ### 2. Define File Location

# %%
# Local on Windows
# directory = '/mnt/c/Users/Dasein/Downloads/'

# Local on External Drive
directory = '/mnt/d/adam-boesky/alpha_beta/0p1_0p75/'

file_path = directory + 'compas_output.h5'

# %% [markdown]
# ### 3. Read and Plot Data

# %%
# df = pd.read_hdf(file_path, key='input_data')

# %%
import h5py as h5

f = h5.File(file_path, 'r')

# %%
list(f.keys())
# Out:
# ['BSE_Common_Envelopes',
#  'BSE_Double_Compact_Objects',
#  'BSE_RLOF',
#  'BSE_Supernovae',
#  'BSE_System_Parameters',
#  'Run_Details']
