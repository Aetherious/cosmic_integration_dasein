# %% [markdown]
# #### HDF5 Keys for Adam Boesky's COMPAS Datasets
#
# - BSE_Common_Envelopes
# - BSE_Double_Compact_Objects
# - BSE_RLOF (Roche Lobe Overflow)
# - BSE_Supernovae
# - BSE_System_Parameters
# - Run_Details
#
# #### COMPAS Output Weights
#
# - alpha + beta
# - sigmaRMS + RMP
#
# #### HDF5 Keys for Lieke van Son's COMPAS Datasets
