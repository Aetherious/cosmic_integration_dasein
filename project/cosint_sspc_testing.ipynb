# %% [markdown]
# ## 0. Setup Star Formation Rate (SFR) w/SSPC

# %%
import copy
# import json
import logging
import os
# import pkg_resources

# from dataclasses import dataclass
# from pathlib import Path
# from typing import Dict, List, Optional, Tuple, Union

import h5py as h5
import numpy as np

import astropy.units as u
import matplotlib.pyplot as plt
import pandas as pd

import sys
sys.path.append('/home/dasein/repositories/stellar-convolution/packages')

from syntheticstellarpopconvolve import convolve, default_convolution_config, default_convolution_instruction
from syntheticstellarpopconvolve.general_functions import extract_unit_dict, generate_boilerplate_outputfile, temp_dir
from syntheticstellarpopconvolve.general_functions import calculate_bincenters, calculate_bin_edges
from syntheticstellarpopconvolve.metallicity_distributions import metallicity_distribution_vanSon2022
from syntheticstellarpopconvolve.starformation_rate_distributions import starformation_rate_distribution_vanSon2023
from syntheticstellarpopconvolve.SFR_dict_plotting_routines import plot_sfr_dict

# %% [markdown]
# ## 1: Setup SFR & Metallicity Distributions

# %%
def setup_sfr_dict(
        directory: str,
        nbins: int = 100,
        nbins_redshift: int = 100,
        min_redshift: int = 0,
        max_redshift: int = 10
):
    """Prepare metallicity and SFR distributions for a dataset."""

    file_path = directory + "compas_output.h5"
    df = pd.read_hdf(file_path, key="input_data")


    pass

# %% [markdown]
# ## High-Level Driver

# %%
def process_dataset():
    pass
