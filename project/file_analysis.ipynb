# %%
import h5py as h5

file_path = '/mnt/d/adam-boesky/alpha_beta/0p1_0p75/compas_output.h5'
f = h5.File(file_path, 'r')

list(f.keys())
# Out:
# ['BSE_Common_Envelopes',
#  'BSE_Double_Compact_Objects',
#  'BSE_RLOF',
#  'BSE_Supernovae',
#  'BSE_System_Parameters',
#  'Run_Details']

# %%
dset = f['BSE_System_Parameters']

print(f.name) # Name of the file (root dir)
print(dset.name) # Name of the selected dataset (dataset dir)
# Out:
# /
# /BSE_System_Parameters
