# %% [markdown]
# Testing SSPC code on COMPAS datasets.

# %%
import numpy as np
import pandas as pd
import astropy.units as u

# %%
from syntheticstellarpopconvolve.general_functions import generate_boilerplate_outputfile
from compas_python_utils.cosmic_integration.ClassCOMPAS import COMPASData
# Out:
# /workspaces/stellar-convolution/project/compas_python_utils/cosmic_integration/totalMassEvolvedPerZ.py:202: SyntaxWarning: invalid escape sequence '\p'
#   p(M) \propto M^-0.3 for M between m1 and m2
